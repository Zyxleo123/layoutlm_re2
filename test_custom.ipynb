# %%
import os
from datasets import load_dataset
import layoutlmft.data.custom_re
import pyarrow
pyarrow.PyExtensionType.set_auto_load(True)
datasets = load_dataset(os.path.abspath(layoutlmft.data.custom_re.__file__))
# Out:
# /root/mambaforge/envs/env/lib/python3.8/site-packages/datasets/features/features.py:648: FutureWarning: pyarrow.PyExtensionType is deprecated and will refuse deserialization by default. Instead, please derive from pyarrow.ExtensionType and implement your own serialization mechanism.
#   pa.PyExtensionType.__init__(self, self.storage_dtype)

# %%
from transformers import AutoTokenizer
from layoutlmft.data.image_utils import RandomResizedCropAndInterpolationWithTwoPic, pil_loader, Compose
from torchvision import transforms
import torch
from timm.data.constants import IMAGENET_INCEPTION_MEAN, IMAGENET_INCEPTION_STD
tokenizer = AutoTokenizer.from_pretrained(
    "./layoutlmv3-base-1028",
    use_fast=True,
)
common_transform = Compose([
    # transforms.ColorJitter(0.4, 0.4, 0.4),
    # transforms.RandomHorizontalFlip(p=0.5),
    RandomResizedCropAndInterpolationWithTwoPic(
        size=224, interpolation="bicubic"),
])
mean = IMAGENET_INCEPTION_MEAN
std = IMAGENET_INCEPTION_STD
patch_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=torch.tensor(mean),
        std=torch.tensor(std))
])
def tokenize_and_align_start_end(examples, augmentation=False):
    tokenized_inputs = tokenizer(
        examples["tokens"],
        padding=False,
        truncation=True,
        return_overflowing_tokens=True,
        # We use this argument because the texts in our dataset are lists of words (with a label for each word).
        is_split_into_words=True,
    )
    bboxes = []
    images = []
    entities = []
    batch_size = len(tokenized_inputs["input_ids"])
    for batch_index in range(batch_size):
        word_ids = tokenized_inputs.word_ids(batch_index=batch_index)
        start_word_idxs = examples["entities"][batch_index]["start"]
        end_word_idxs = examples["entities"][batch_index]["end"]
        aligned_start_word_idxs = []
        aligned_end_word_idxs = []
        bbox = examples["bboxes"][batch_index]
        previous_word_idx = None
        for start_word_idx, end_word_idx in zip(start_word_idxs, end_word_idxs):
            bbox_inputs = []
            start_token_idx = None
            end_token_idx = None
            # Inner loop: one pass word_ids to find the start/end token idx(end token idx is the first token of the next word)
            for token_idx, word_idx in enumerate(word_ids):
                # Special tokens have a word id that is None.
                if word_idx is None:
                    bbox_inputs.append([0, 0, 0, 0])
                # the first token of each word.
                elif word_idx != previous_word_idx:
                    bbox_inputs.append(bbox[word_idx])
                    if word_idx == start_word_idx:
                        start_token_idx = token_idx
                    if word_idx == end_word_idx:
                        end_token_idx = token_idx
                else:
                    bbox_inputs.append(bbox[word_idx])
                previous_word_idx = word_idx
            assert start_token_idx is not None
            if end_token_idx is None:
                end_token_idx = len(word_ids) - 1 # -1 because the last token is a special token
            aligned_start_word_idxs.append(start_token_idx)
            aligned_end_word_idxs.append(end_token_idx)
            
        bboxes.append(bbox_inputs)
        entities.append({
            "start": aligned_start_word_idxs,
            "end": aligned_end_word_idxs,
            "label": examples["entities"][batch_index]["label"],
        })
        ipath = examples["image_path"][batch_index]
        img = pil_loader(ipath)
        for_patches, _ = common_transform(img, augmentation=augmentation)
        patch = patch_transform(for_patches)
        images.append(patch)
    tokenized_inputs["bbox"] = bboxes
    tokenized_inputs["entities"] = entities
    tokenized_inputs["relations"] = examples["relations"]
    # dummy labels because huggingface trainer needs them
    tokenized_inputs["labels"] = [10000] * batch_size
    tokenized_inputs["images"] = images
    return tokenized_inputs

# %%
# remove everything except image_path
remove_columns = [column for column in datasets["train"].column_names if column not in ["image_path"]]
train_dataset = datasets["train"].map(
    tokenize_and_align_start_end, batched=True, batch_size=1, remove_columns=remove_columns
)
test_dataset = datasets["test"].map(
    tokenize_and_align_start_end, batched=True, batch_size=1, remove_columns=remove_columns
)

# %% [markdown]
# # Validate bounding boxes

# %%
from PIL import ImageDraw
from PIL import Image

def unnormalize_box(bbox, width, height):
     return [
         width * (bbox[0] / 1000),
         height * (bbox[1] / 1000),
         width * (bbox[2] / 1000),
         height * (bbox[3] / 1000),
     ]

def draw_boxes(image, boxes, color='red', width=2):
    draw = ImageDraw.Draw(image)
    for box in boxes:
        draw.rectangle(unnormalize_box(box, image.width, image.height), outline=color, width=width)
    return image

for dataset in (train_dataset, test_dataset):
    for i, example in enumerate(dataset):
        if i == 10:
            break
        image = Image.open(example['image_path'])
        draw_boxes(image, example['bbox']).show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=771x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=762x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>
# <PIL.PngImagePlugin.PngImageFile image mode=L size=754x1000>

# %% [markdown]
# # Validate the consistency between entities and relations

# %%
label_id_map = {0: "header", 1: "question", 2: "answer", 3: "other"}
def decode_relation(example, relations, entities):
    for head, tail in zip(relations['head'], relations['tail']):
        head_decoded = tokenizer.decode(example['input_ids'][entities['start'][head]:entities['end'][head]])
        tail_decoded = tokenizer.decode(example['input_ids'][entities['start'][tail]:entities['end'][tail]])
        head_type = entities['label'][head]
        tail_type = entities['label'][tail]
        print(f"|{head_decoded}| ({label_id_map[head_type]}) -> |{tail_decoded}| ({label_id_map[tail_type]})")

for dataset in (test_dataset, train_dataset):
    for i in range(len(dataset)):
        if i == 10:
            break
        example = dataset[i]
        entities = example['entities']
        relations = example['relations']
        decode_relation(example, relations, entities)
        break
# Out:
# | TO:| (question) -> | George Baroody| (answer)
# | DATE:| (question) -> | 12 /10 /98| (answer)
# | NUMBER OF PAGES INCLUDING COVER SHEET:| (question) -> | 3| (answer)
# | Fax:| (question) -> | 614 -466 -5087| (answer)
# | NOTE:| (question) -> | THIS MESSAGE IS INTENDED ONLY FOR THE USE OF THE INDIVIDUAL OR ENTITY TO WHOM IT IS ADDRESSED AND MAY CONTAIN INFORMATION THAT IS PRIVILEGED. CONFIDENTIAL, AND EXEMPT FROM DISCLOSURE UNDER APPLICABLE LAW. If the reader of this message is not the intended recipient of the employee or agent responsible for delivering the message to the intended recipient, you are hereby notified that any dissemination, distribution, copying, or conveying of this communication in any manner is strictly prohibited. If you have received this comunication in error, please notify us immediately by telephone and return the original message to us at the address below via the U. S. Postal Service. Thank you for your cooperation.| (answer)
# | FAX NO.| (question) -> | (614) 466- 5087| (answer)
# | FAX NUMBER:| (question) -> | (336) 335- 7392| (answer)
# | PHONE NUMBER:| (question) -> | (336) 335- 7363| (answer)
# | SENDER /PHONE NUMBER:| (question) -> | June Flynn for Eric Brown/ (614) 466- 8980| (answer)
# | Suggestion:| (question) -> | Discontinue coal retention analyses on licensee submitted product samples (Note : Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in ciparettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity. )| (answer)
# | Date:| (question) -> | 9/ 3/ 92| (answer)
# | R&D Group:| (question) -> | Licensee| (answer)
# | Have you contacted your Manager/ Supervisor?| (header) -> | Yes| (question)
# | Have you contacted your Manager/ Supervisor?| (header) -> | No| (question)
# | Name / Phone Ext. :| (question) -> | M. Hamann P. Harper, P. Martinez| (answer)
# | Supervisor / Manager :| (question) -> | J. S. Wigand| (answer)
# | Suggested Solutions (s) :| (question) -> | Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.| (answer)
# | Manager Comments:| (question) -> | Manager, please contact suggester and forward comments to the Quality Council.| (answer)

# %% [markdown]
# # Validate relation generation

# %%
def build_relation(relations, entities):
    batch_size = len(relations)
    new_relations = []
    for b in range(batch_size):
        if len(entities[b]["start"]) <= 2:
            entities[b] = {"end": [1, 1], "label": [0, 0], "start": [0, 0]}
        all_possible_relations = []
        for i in range(len(entities[b]["label"])):
            for j in range(len(entities[b]["label"])):
                if entities[b]["label"][i] == 1 and entities[b]["label"][j] == 2:
                    all_possible_relations.append((i, j))
        all_possible_relations = set(all_possible_relations)
        if len(all_possible_relations) == 0:
            all_possible_relations = set([(0, 1)])
        positive_relations = set(list(zip(relations[b]["head"], relations[b]["tail"])))
        negative_relations = all_possible_relations - positive_relations
        positive_relations = set([i for i in positive_relations if i in all_possible_relations])
        reordered_relations = list(positive_relations) + list(negative_relations)
        relation_per_doc = {"head": [], "tail": [], "label": []}
        relation_per_doc["head"] = [i[0] for i in reordered_relations]
        relation_per_doc["tail"] = [i[1] for i in reordered_relations]
        relation_per_doc["label"] = [1] * len(positive_relations) + [0] * (
            len(reordered_relations) - len(positive_relations)
        )
        assert len(relation_per_doc["head"]) != 0
        new_relations.append(relation_per_doc)
    return new_relations, entities

# %%
for dataset in (train_dataset, test_dataset):
    for i in range(len(dataset)):
        example = dataset[i]
        entities = [example['entities']]
        relations = [example['relations']]
        new_relations, new_entities = build_relation(relations, entities)
        new_labels = new_relations[0]['label'] 
        entity_labels = new_entities[0]['label']
        n_question = sum([1 for i in entity_labels if i == 1])
        n_answer = sum([1 for i in entity_labels if i == 2])
        try:
            assert len(new_labels) == n_question * n_answer
        except AssertionError:
            if n_question == 0 or n_answer == 0:
                print(f"Although (n_q){n_question} * (n_a){n_answer} != {len(new_labels)}, but it's because there is no question or answer in this document.")
        print(f"total relations:", len(new_labels), f"= (n_q){n_question} * (n_a){n_answer}")
        print(f"positive relations:", sum(new_relations[0]['label']))
        print(f"negative relations:", len(new_labels) - sum(new_relations[0]['label']))
# Out:
# total relations: 70 = (n_q)10 * (n_a)7
# positive relations: 7
# negative relations: 63
# total relations: 1932 = (n_q)46 * (n_a)42
# positive relations: 42
# negative relations: 1890
# total relations: 156 = (n_q)13 * (n_a)12
# positive relations: 12
# negative relations: 144
# total relations: 4687 = (n_q)43 * (n_a)109
# positive relations: 195
# negative relations: 4492
# total relations: 69 = (n_q)3 * (n_a)23
# positive relations: 23
# negative relations: 46
# total relations: 240 = (n_q)20 * (n_a)12
# positive relations: 12
# negative relations: 228
# total relations: 192 = (n_q)16 * (n_a)12
# positive relations: 14
# negative relations: 178
# total relations: 1008 = (n_q)28 * (n_a)36
# positive relations: 60
# negative relations: 948
# total relations: 364 = (n_q)14 * (n_a)26
# positive relations: 26
# negative relations: 338
# total relations: 882 = (n_q)21 * (n_a)42
# positive relations: 74
# negative relations: 808
# total relations: 1040 = (n_q)26 * (n_a)40
# positive relations: 66
# negative relations: 974
# total relations: 1890 = (n_q)45 * (n_a)42
# positive relations: 42
# negative relations: 1848
# total relations: 30 = (n_q)5 * (n_a)6
# positive relations: 6
# negative relations: 24
# total relations: 506 = (n_q)22 * (n_a)23
# positive relations: 35
# negative relations: 471
# total relations: 231 = (n_q)21 * (n_a)11
# positive relations: 11
# negative relations: 220
# total relations: 153 = (n_q)17 * (n_a)9
# positive relations: 11
# negative relations: 142
# total relations: 1280 = (n_q)32 * (n_a)40
# positive relations: 40
# negative relations: 1240
# total relations: 80 = (n_q)10 * (n_a)8
# positive relations: 8
# negative relations: 72
# total relations: 1710 = (n_q)45 * (n_a)38
# positive relations: 38
# negative relations: 1672
# total relations: 323 = (n_q)19 * (n_a)17
# positive relations: 17
# negative relations: 306
# total relations: 775 = (n_q)31 * (n_a)25
# positive relations: 29
# negative relations: 746
# total relations: 88 = (n_q)11 * (n_a)8
# positive relations: 9
# negative relations: 79
# total relations: 72 = (n_q)9 * (n_a)8
# positive relations: 8
# negative relations: 64
# total relations: 143 = (n_q)13 * (n_a)11
# positive relations: 11
# negative relations: 132
# total relations: 132 = (n_q)12 * (n_a)11
# positive relations: 11
# negative relations: 121
# total relations: 1080 = (n_q)54 * (n_a)20
# positive relations: 24
# negative relations: 1056
# total relations: 390 = (n_q)30 * (n_a)13
# positive relations: 16
# negative relations: 374
# total relations: 396 = (n_q)18 * (n_a)22
# positive relations: 22
# negative relations: 374
# total relations: 99 = (n_q)9 * (n_a)11
# positive relations: 11
# negative relations: 88
# total relations: 405 = (n_q)45 * (n_a)9
# positive relations: 9
# negative relations: 396
# total relations: 105 = (n_q)7 * (n_a)15
# positive relations: 15
# negative relations: 90
# total relations: 874 = (n_q)38 * (n_a)23
# positive relations: 26
# negative relations: 848
# total relations: 1482 = (n_q)39 * (n_a)38
# positive relations: 38
# negative relations: 1444
# total relations: 1512 = (n_q)54 * (n_a)28
# positive relations: 28
# negative relations: 1484
# total relations: 546 = (n_q)26 * (n_a)21
# positive relations: 21
# negative relations: 525
# total relations: 27 = (n_q)9 * (n_a)3
# positive relations: 3
# negative relations: 24
# total relations: 875 = (n_q)35 * (n_a)25
# positive relations: 25
# negative relations: 850
# total relations: 34 = (n_q)17 * (n_a)2
# positive relations: 2
# negative relations: 32
# total relations: 18 = (n_q)3 * (n_a)6
# positive relations: 6
# negative relations: 12
# total relations: 377 = (n_q)29 * (n_a)13
# positive relations: 13
# negative relations: 364
# total relations: 170 = (n_q)10 * (n_a)17
# positive relations: 17
# negative relations: 153
# total relations: 280 = (n_q)20 * (n_a)14
# positive relations: 14
# negative relations: 266
# Although (n_q)10 * (n_a)0 != 1, but it's because there is no question or answer in this document.
# total relations: 1 = (n_q)10 * (n_a)0
# positive relations: 0
# negative relations: 1
# total relations: 435 = (n_q)29 * (n_a)15
# positive relations: 19
# negative relations: 416
# total relations: 289 = (n_q)17 * (n_a)17
# positive relations: 17
# negative relations: 272
# total relations: 432 = (n_q)27 * (n_a)16
# positive relations: 16
# negative relations: 416
# total relations: 832 = (n_q)32 * (n_a)26
# positive relations: 26
# negative relations: 806
# total relations: 192 = (n_q)24 * (n_a)8
# positive relations: 8
# negative relations: 184
# total relations: 24 = (n_q)12 * (n_a)2
# positive relations: 2
# negative relations: 22
# total relations: 560 = (n_q)14 * (n_a)40
# positive relations: 76
# negative relations: 484
# total relations: 72 = (n_q)8 * (n_a)9
# positive relations: 9
# negative relations: 63
# total relations: 169 = (n_q)13 * (n_a)13
# positive relations: 13
# negative relations: 156
# total relations: 304 = (n_q)19 * (n_a)16
# positive relations: 17
# negative relations: 287
# total relations: 340 = (n_q)20 * (n_a)17
# positive relations: 17
# negative relations: 323
# total relations: 285 = (n_q)15 * (n_a)19
# positive relations: 19
# negative relations: 266
# total relations: 144 = (n_q)12 * (n_a)12
# positive relations: 12
# negative relations: 132
# total relations: 1170 = (n_q)39 * (n_a)30
# positive relations: 30
# negative relations: 1140
# total relations: 756 = (n_q)36 * (n_a)21
# positive relations: 21
# negative relations: 735
# total relations: 238 = (n_q)17 * (n_a)14
# positive relations: 14
# negative relations: 224
# total relations: 64 = (n_q)8 * (n_a)8
# positive relations: 8
# negative relations: 56
# total relations: 868 = (n_q)31 * (n_a)28
# positive relations: 28
# negative relations: 840
# total relations: 144 = (n_q)12 * (n_a)12
# positive relations: 12
# negative relations: 132
# total relations: 56 = (n_q)8 * (n_a)7
# positive relations: 7
# negative relations: 49
# total relations: 1209 = (n_q)31 * (n_a)39
# positive relations: 45
# negative relations: 1164
# total relations: 126 = (n_q)14 * (n_a)9
# positive relations: 9
# negative relations: 117
# total relations: 1056 = (n_q)22 * (n_a)48
# positive relations: 74
# negative relations: 982
# total relations: 49 = (n_q)7 * (n_a)7
# positive relations: 7
# negative relations: 42
# total relations: 136 = (n_q)17 * (n_a)8
# positive relations: 8
# negative relations: 128
# total relations: 88 = (n_q)11 * (n_a)8
# positive relations: 8
# negative relations: 80
# total relations: 372 = (n_q)31 * (n_a)12
# positive relations: 13
# negative relations: 359
# total relations: 240 = (n_q)15 * (n_a)16
# positive relations: 16
# negative relations: 224
# total relations: 384 = (n_q)32 * (n_a)12
# positive relations: 12
# negative relations: 372
# total relations: 288 = (n_q)24 * (n_a)12
# positive relations: 13
# negative relations: 275
# total relations: 255 = (n_q)17 * (n_a)15
# positive relations: 15
# negative relations: 240
# total relations: 210 = (n_q)21 * (n_a)10
# positive relations: 10
# negative relations: 200
# total relations: 2074 = (n_q)34 * (n_a)61
# positive relations: 67
# negative relations: 2007
# total relations: 2009 = (n_q)49 * (n_a)41
# positive relations: 45
# negative relations: 1964
# total relations: 99 = (n_q)11 * (n_a)9
# positive relations: 9
# negative relations: 90
# total relations: 72 = (n_q)9 * (n_a)8
# positive relations: 8
# negative relations: 64
# total relations: 182 = (n_q)14 * (n_a)13
# positive relations: 13
# negative relations: 169
# total relations: 155 = (n_q)31 * (n_a)5
# positive relations: 5
# negative relations: 150
# total relations: 2090 = (n_q)55 * (n_a)38
# positive relations: 38
# negative relations: 2052
# total relations: 50 = (n_q)10 * (n_a)5
# positive relations: 5
# negative relations: 45
# total relations: 54 = (n_q)9 * (n_a)6
# positive relations: 6
# negative relations: 48
# total relations: 736 = (n_q)32 * (n_a)23
# positive relations: 23
# negative relations: 713
# total relations: 304 = (n_q)19 * (n_a)16
# positive relations: 16
# negative relations: 288
# total relations: 594 = (n_q)54 * (n_a)11
# positive relations: 11
# negative relations: 583
# total relations: 132 = (n_q)12 * (n_a)11
# positive relations: 11
# negative relations: 121
# total relations: 520 = (n_q)40 * (n_a)13
# positive relations: 13
# negative relations: 507
# total relations: 228 = (n_q)19 * (n_a)12
# positive relations: 12
# negative relations: 216
# total relations: 1176 = (n_q)42 * (n_a)28
# positive relations: 29
# negative relations: 1147
# total relations: 156 = (n_q)13 * (n_a)12
# positive relations: 12
# negative relations: 144
# total relations: 1496 = (n_q)44 * (n_a)34
# positive relations: 34
# negative relations: 1462
# total relations: 187 = (n_q)17 * (n_a)11
# positive relations: 11
# negative relations: 176
# total relations: 468 = (n_q)18 * (n_a)26
# positive relations: 26
# negative relations: 442
# total relations: 195 = (n_q)13 * (n_a)15
# positive relations: 15
# negative relations: 180
# total relations: 777 = (n_q)37 * (n_a)21
# positive relations: 24
# negative relations: 753
# total relations: 595 = (n_q)35 * (n_a)17
# positive relations: 17
# negative relations: 578
# total relations: 156 = (n_q)13 * (n_a)12
# positive relations: 12
# negative relations: 144
# total relations: 121 = (n_q)11 * (n_a)11
# positive relations: 11
# negative relations: 110
# total relations: 220 = (n_q)20 * (n_a)11
# positive relations: 11
# negative relations: 209
# Although (n_q)7 * (n_a)0 != 1, but it's because there is no question or answer in this document.
# total relations: 1 = (n_q)7 * (n_a)0
# positive relations: 0
# negative relations: 1
# total relations: 99 = (n_q)11 * (n_a)9
# positive relations: 9
# negative relations: 90
# total relations: 2162 = (n_q)47 * (n_a)46
# positive relations: 54
# negative relations: 2108
# total relations: 665 = (n_q)35 * (n_a)19
# positive relations: 19
# negative relations: 646
# total relations: 1320 = (n_q)33 * (n_a)40
# positive relations: 40
# negative relations: 1280
# total relations: 1008 = (n_q)28 * (n_a)36
# positive relations: 42
# negative relations: 966
# total relations: 480 = (n_q)24 * (n_a)20
# positive relations: 24
# negative relations: 456
# total relations: 420 = (n_q)21 * (n_a)20
# positive relations: 21
# negative relations: 399
# total relations: 1353 = (n_q)33 * (n_a)41
# positive relations: 41
# negative relations: 1312
# total relations: 66 = (n_q)22 * (n_a)3
# positive relations: 3
# negative relations: 63
# total relations: 20 = (n_q)10 * (n_a)2
# positive relations: 2
# negative relations: 18
# total relations: 304 = (n_q)19 * (n_a)16
# positive relations: 16
# negative relations: 288
# total relations: 320 = (n_q)16 * (n_a)20
# positive relations: 23
# negative relations: 297
# total relations: 36 = (n_q)6 * (n_a)6
# positive relations: 6
# negative relations: 30
# total relations: 143 = (n_q)13 * (n_a)11
# positive relations: 11
# negative relations: 132
# total relations: 493 = (n_q)29 * (n_a)17
# positive relations: 17
# negative relations: 476
# total relations: 490 = (n_q)14 * (n_a)35
# positive relations: 35
# negative relations: 455
# total relations: 5112 = (n_q)71 * (n_a)72
# positive relations: 72
# negative relations: 5040
# total relations: 51 = (n_q)17 * (n_a)3
# positive relations: 3
# negative relations: 48
# total relations: 192 = (n_q)8 * (n_a)24
# positive relations: 24
# negative relations: 168
# total relations: 216 = (n_q)9 * (n_a)24
# positive relations: 24
# negative relations: 192
# total relations: 55 = (n_q)11 * (n_a)5
# positive relations: 5
# negative relations: 50
# total relations: 110 = (n_q)10 * (n_a)11
# positive relations: 11
# negative relations: 99
# total relations: 400 = (n_q)20 * (n_a)20
# positive relations: 20
# negative relations: 380
# total relations: 340 = (n_q)20 * (n_a)17
# positive relations: 17
# negative relations: 323
# total relations: 340 = (n_q)20 * (n_a)17
# positive relations: 17
# negative relations: 323
# total relations: 135 = (n_q)15 * (n_a)9
# positive relations: 9
# negative relations: 126
# total relations: 54 = (n_q)27 * (n_a)2
# positive relations: 2
# negative relations: 52
# total relations: 63 = (n_q)9 * (n_a)7
# positive relations: 7
# negative relations: 56
# total relations: 156 = (n_q)26 * (n_a)6
# positive relations: 6
# negative relations: 150
# total relations: 320 = (n_q)20 * (n_a)16
# positive relations: 16
# negative relations: 304
# total relations: 42 = (n_q)14 * (n_a)3
# positive relations: 3
# negative relations: 39
# total relations: 528 = (n_q)22 * (n_a)24
# positive relations: 37
# negative relations: 491
# total relations: 837 = (n_q)27 * (n_a)31
# positive relations: 31
# negative relations: 806
# total relations: 525 = (n_q)35 * (n_a)15
# positive relations: 15
# negative relations: 510
# total relations: 595 = (n_q)35 * (n_a)17
# positive relations: 17
# negative relations: 578
# total relations: 24 = (n_q)6 * (n_a)4
# positive relations: 4
# negative relations: 20
# total relations: 99 = (n_q)11 * (n_a)9
# positive relations: 9
# negative relations: 90
# total relations: 30 = (n_q)6 * (n_a)5
# positive relations: 5
# negative relations: 25
# total relations: 156 = (n_q)13 * (n_a)12
# positive relations: 12
# negative relations: 144
# total relations: 135 = (n_q)15 * (n_a)9
# positive relations: 9
# negative relations: 126
# total relations: 160 = (n_q)16 * (n_a)10
# positive relations: 10
# negative relations: 150
# total relations: 180 = (n_q)12 * (n_a)15
# positive relations: 15
# negative relations: 165
# total relations: 720 = (n_q)30 * (n_a)24
# positive relations: 24
# negative relations: 696
# total relations: 319 = (n_q)11 * (n_a)29
# positive relations: 29
# negative relations: 290
# total relations: 440 = (n_q)22 * (n_a)20
# positive relations: 20
# negative relations: 420
# total relations: 902 = (n_q)22 * (n_a)41
# positive relations: 41
# negative relations: 861
# total relations: 216 = (n_q)8 * (n_a)27
# positive relations: 27
# negative relations: 189
# total relations: 90 = (n_q)10 * (n_a)9
# positive relations: 9
# negative relations: 81
# total relations: 651 = (n_q)21 * (n_a)31
# positive relations: 31
# negative relations: 620
# total relations: 238 = (n_q)17 * (n_a)14
# positive relations: 14
# negative relations: 224
# total relations: 180 = (n_q)18 * (n_a)10
# positive relations: 10
# negative relations: 170
# total relations: 240 = (n_q)24 * (n_a)10
# positive relations: 10
# negative relations: 230
# total relations: 238 = (n_q)17 * (n_a)14
# positive relations: 14
# negative relations: 224
# total relations: 850 = (n_q)25 * (n_a)34
# positive relations: 34
# negative relations: 816
# total relations: 1984 = (n_q)32 * (n_a)62
# positive relations: 62
# negative relations: 1922
# total relations: 374 = (n_q)22 * (n_a)17
# positive relations: 17
# negative relations: 357
# total relations: 70 = (n_q)10 * (n_a)7
# positive relations: 7
# negative relations: 63
# total relations: 60 = (n_q)10 * (n_a)6
# positive relations: 6
# negative relations: 54
# total relations: 162 = (n_q)18 * (n_a)9
# positive relations: 9
# negative relations: 153
# total relations: 20 = (n_q)5 * (n_a)4
# positive relations: 4
# negative relations: 16
# total relations: 108 = (n_q)12 * (n_a)9
# positive relations: 9
# negative relations: 99
# total relations: 144 = (n_q)12 * (n_a)12
# positive relations: 12
# negative relations: 132
# total relations: 406 = (n_q)14 * (n_a)29
# positive relations: 29
# negative relations: 377
# total relations: 319 = (n_q)11 * (n_a)29
# positive relations: 29
# negative relations: 290
# total relations: 36 = (n_q)6 * (n_a)6
# positive relations: 6
# negative relations: 30
# total relations: 180 = (n_q)15 * (n_a)12
# positive relations: 12
# negative relations: 168
# total relations: 16 = (n_q)4 * (n_a)4
# positive relations: 4
# negative relations: 12
# total relations: 1860 = (n_q)31 * (n_a)60
# positive relations: 60
# negative relations: 1800
# total relations: 140 = (n_q)14 * (n_a)10
# positive relations: 10
# negative relations: 130
# total relations: 140 = (n_q)14 * (n_a)10
# positive relations: 10
# negative relations: 130
# total relations: 374 = (n_q)22 * (n_a)17
# positive relations: 17
# negative relations: 357
# Although (n_q)21 * (n_a)0 != 1, but it's because there is no question or answer in this document.
# total relations: 1 = (n_q)21 * (n_a)0
# positive relations: 0
# negative relations: 1
# total relations: 90 = (n_q)9 * (n_a)10
# positive relations: 10
# negative relations: 80
# Although (n_q)11 * (n_a)0 != 1, but it's because there is no question or answer in this document.
# total relations: 1 = (n_q)11 * (n_a)0
# positive relations: 0
# negative relations: 1
# Although (n_q)35 * (n_a)0 != 1, but it's because there is no question or answer in this document.
# total relations: 1 = (n_q)35 * (n_a)0
# positive relations: 0
# negative relations: 1
# total relations: 322 = (n_q)23 * (n_a)14
# positive relations: 15
# negative relations: 307
# total relations: 30 = (n_q)30 * (n_a)1
# positive relations: 1
# negative relations: 29
# total relations: 88 = (n_q)11 * (n_a)8
# positive relations: 8
# negative relations: 80
# total relations: 910 = (n_q)26 * (n_a)35
# positive relations: 35
# negative relations: 875
# total relations: 80 = (n_q)10 * (n_a)8
# positive relations: 8
# negative relations: 72
# total relations: 96 = (n_q)12 * (n_a)8
# positive relations: 8
# negative relations: 88
# total relations: 154 = (n_q)14 * (n_a)11
# positive relations: 11
# negative relations: 143
# total relations: 1482 = (n_q)39 * (n_a)38
# positive relations: 38
# negative relations: 1444
# total relations: 99 = (n_q)11 * (n_a)9
# positive relations: 9
# negative relations: 90
# total relations: 2115 = (n_q)47 * (n_a)45
# positive relations: 54
# negative relations: 2061
# total relations: 120 = (n_q)12 * (n_a)10
# positive relations: 11
# negative relations: 109
# total relations: 323 = (n_q)19 * (n_a)17
# positive relations: 17
# negative relations: 306
# total relations: 242 = (n_q)22 * (n_a)11
# positive relations: 11
# negative relations: 231
# total relations: 216 = (n_q)36 * (n_a)6
# positive relations: 6
# negative relations: 210
# total relations: 187 = (n_q)17 * (n_a)11
# positive relations: 11
# negative relations: 176
# total relations: 688 = (n_q)43 * (n_a)16
# positive relations: 16
# negative relations: 672
# total relations: 1479 = (n_q)51 * (n_a)29
# positive relations: 29
# negative relations: 1450
# total relations: 1032 = (n_q)43 * (n_a)24
# positive relations: 27
# negative relations: 1005
# total relations: 374 = (n_q)22 * (n_a)17
# positive relations: 17
# negative relations: 357
# total relations: 837 = (n_q)31 * (n_a)27
# positive relations: 27
# negative relations: 810
# total relations: 903 = (n_q)43 * (n_a)21
# positive relations: 22
# negative relations: 881
# total relations: 170 = (n_q)17 * (n_a)10
# positive relations: 10
# negative relations: 160

# %%
import json
from layoutlmft.data.image_utils import load_image, normalize_bbox
def get_line_bbox(bboxs):
    x = [bboxs[i][j] for i in range(len(bboxs)) for j in range(0, len(bboxs[i]), 2)]
    y = [bboxs[i][j] for i in range(len(bboxs)) for j in range(1, len(bboxs[i]), 2)]

    x0, y0, x1, y1 = min(x), min(y), max(x), max(y)

    assert x1 >= x0 and y1 >= y0
    bbox = [[x0, y0, x1, y1] for _ in range(len(bboxs))]
    return bbox

def generate_examples(filepath, img_dir):
    ann_dir = filepath
    split = "training" if "training" in filepath else "testing"
    img_dir = os.path.join(img_dir, split+"_data")
    for i, file in enumerate(sorted(os.listdir(ann_dir))):
        tokens = []
        bboxes = []

        file_path = os.path.join(ann_dir, file)
        with open(file_path, "r", encoding="utf8") as f:
            data = json.load(f)
            doc = data["document"]
        n_entity = len(data["label_entities"])
        n_relation = len(data["label_linkings"])

        image_path = os.path.join(img_dir, data["img"]["fname"])
        image, size = load_image(image_path)
            
        # iterate through data["document"] to strip off empty words,
        # and get a mapping from the origin id to the id after stripping 
        origin_id_to_stripped_id = {}
        stripped_id = 0
        for item in doc:
            cur_line_bboxes = []
            words= item["words"]
            stripped_words = []
            for w in words:
                if w["text"].strip() == "":
                    continue
                wid = w["id"]
                origin_id_to_stripped_id[wid] = stripped_id
                stripped_id += 1
                stripped_words.append(w)
                tokens.append(w["text"])
                cur_line_bboxes.append(normalize_bbox(w["box"], size))
            if len(stripped_words) == 0:
                continue
            # by default: --segment_level_layout 1
            # if do not want to use segment_level_layout, comment the following line
            cur_line_bboxes = get_line_bbox(cur_line_bboxes)
            # box = normalize_bbox(item["box"], size)
            # cur_line_bboxes = [box for _ in range(len(words))]
            bboxes.extend(cur_line_bboxes)
            
        # decide the start and end of every entity based on origin_id_to_stripped_id
        label_id_map = {"header": 0, "question": 1, "answer": 2, "other": 3}
        entities = []
        for i, entity in enumerate(data["label_entities"]):
            assert i == entity["entity_id"]
            cur_entity = {}
            n_entity_words = len(entity["word_idx"])
            assert n_entity_words > 0
            prev_word_idx = -1
            for j in range(n_entity_words):
                if j == 0:
                    prev_word_idx = entity["word_idx"][j]
                    continue
                assert entity["word_idx"][j] == prev_word_idx + 1
                prev_word_idx = entity["word_idx"][j]
            for start_i in range(n_entity_words):
                if entity["word_idx"][start_i] in origin_id_to_stripped_id:
                    cur_entity["start"] = origin_id_to_stripped_id[entity["word_idx"][start_i]]
                    break
            for end_i in range(n_entity_words-1, -1, -1):
                if entity["word_idx"][end_i] in origin_id_to_stripped_id:
                    cur_entity["end"] = origin_id_to_stripped_id[entity["word_idx"][end_i]] + 1
                    break
            cur_entity["label"] = label_id_map[entity["label"]]
            assert cur_entity["label"] != 3
            assert len(cur_entity) == 3
            entities.append(cur_entity)    
            
        relations = []
            
        for relation in data["label_linkings"]:
            cur_relation = {}
            assert relation[0] < n_entity and relation[1] < n_entity
            cur_relation["head"], cur_relation["tail"] = relation
            relations.append(cur_relation) 

        uid = data["uid"]
        yield uid, {
            "id": uid,
            "tokens": tokens,
            "bboxes": bboxes,
            "entities": entities,
            "relations": relations,
            "image": image,
            "image_path": image_path,
        }

# %%
img_dir = "/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/"
custom_ds = "./layoutlmft/data/datasets/testing_data"
generator = generate_examples(custom_ds, img_dir)
for uid, example in generator:
    print(uid)
    print(example)
# Out:
# 82092117
# {'id': '82092117', 'tokens': ['<unk>', 'SENDER', '/PHONE', 'NUMBER:', 'TO:', 'FAX', 'NUMBER:', 'DATE:', 'NUMBER', 'OF', 'PAGES', 'INCLUDING', 'COVER', 'SHEET:', 'ATT.', 'GEN.', 'ADMIN.', 'OFFICE', 'Fax:', '614', '-466', '-5087', 'SPECIAL', 'INSTRUCTIONS:', 'NOTE:', 'George', 'Baroody', 'Attorney', 'General', 'Betty', 'D.', 'Montgomery', 'THIS', 'MESSAGE', 'IS', 'INTENDED', 'ONLY', 'FOR', 'THE', 'USE', 'OF', 'THE', 'INDIVIDUAL', 'OR', 'ENTITY', 'TO', 'WHOM', 'IT', 'IS', 'ADDRESSED', 'AND', 'MAY', 'CONTAIN', 'INFORMATION', 'THAT', 'IS', 'PRIVILEGED.', 'CONFIDENTIAL,', 'AND', 'EXEMPT', 'FROM', 'DISCLOSURE', 'UNDER', 'APPLICABLE', 'LAW.', 'If', 'the', 'reader', 'of', 'this', 'message', 'is', 'not', 'the', 'intended', 'recipient', 'of', 'the', 'employee', 'or', 'agent', 'responsible', 'for', 'delivering', 'the', 'message', 'to', 'the', 'intended', 'recipient,', 'you', 'are', 'hereby', 'notified', 'that', 'any', 'dissemination,', 'distribution,', 'copying,', 'or', 'conveying', 'of', 'this', 'communication', 'in', 'any', 'manner', 'is', 'strictly', '
...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/82200067_0069.png'}
# 82250337_0338
# {'id': '82250337_0338', 'tokens': ['FROM:', 'PRICE', 'POINT:', 'CHAINS', 'ACCEPTANCE/', 'MERCHANDISING:', 'INDEPENDENTS', 'ACCEPTANCE/', 'MERCHANDISING:', 'TO:', 'REPORTING', 'PERIODS:', 'SALES', 'FORCE', 'INVOLVEMENT:', 'They', 'have', 'crew-', 'worked', 'distribution,', 'and', 'it', 'is', 'reported', 'that', 'they', 'may', 'crew-', 'work', 'it', 'again', 'Sales', 'force', 'has', 'been', 'busy', 'promoting', 'old', 'style', 'backs', 'to', 'clean', 'up', 'inventory.', 'All', 'POS', 'is', 'being', 'converted', 'to', '"B"', 'Kool.', 'DISTRIBUTORS', 'ACCEPTANCE', 'INTRO', 'TERMS', 'INTRO', 'DEALS', 'INVOLVEMENT:', 'All', 'accounts', 'have', 'the', 'new', 'packaging.', 'It', 'was', 'not', 'a', 'problem', 'obtaining', 'new', 'distribution.', 'All', 'accounts', 'appear', 'to', 'have', '100%', 'distribution', 'of', 'new', 'packings.', 'Very', 'well', 'received.', 'The', 'old', 'packs', 'are', 'peing', 'consolidated', 'and', 'promoted', 'in', 'select', 'retail', 'locations', 'at', '40', 'off', '$4', '00', 'off', 'cartons.', 'ADVERTISING', 'EFFECTIVENESS', 'OF', 'P.', 'O.', 'S.:', 'The', 'theme', '"B"', 'Kool', 'has', 'replaced', 'all', 'previous', 'POS.', 'They', 'have', 'effectively', 'replaced', 'all', 'old', 'POS.', 'New', 'door', 'signage,', 'hour', 'signs,', 'poster', 'mats,', 'and', 'clocks', 'have', 'the', 'new', 'design.', '"B"', 'Kool', 'also', 'appears', 'on', 'billboards', 'in', 'llinois.', 'DATE:', 'TEST', 'MARKET', 'GEOGRAPHY:', 'This', 'has', 'not', 'been', 'a', 'problem.', 'New', 'packaging', 'is', 'just', 'following', 'up', 'on', 'the', 'old', '"packaging".', '2-', 'Dec-', '97', 'Sam', 'Zolot', 'D.', 'J.', 'Landro', 'FULLS', '$', 'P/', 'V', '$', 'COMPETITIVE', 'PRODUCT', 'INTRODUCTION', 'PROGRESS', 'REPORT', 'Oct.', 'MANUFACTURER:', 'BRAND:', 'Divisions', '621', 'and', '627', 'wisconsin', 'TYPE', 'OF', 'PACKINGS:', '(Indicate', "Distributor's", 'Cost', 'Per', 'Carton)', 'PAGE', '1', 'OF', '2', 'Nov.', 'X', 'Kool', 'Waterfall', 'B&W', 'All', 'Packings', 'Dec.', 'Jan.', '82250337'], 'bboxes': [[122, 219, 169, 232], [122, 358, 220, 371], [122, 358, 220, 371], [122, 609, 420, 623], [122, 609, 420, 623], [122, 609, 420, 623], [122, 716, 476, 731], [122, 716, 476, 731], [122, 716, 476, 731], [124, 200, 151, 214], [124, 271, 282, 285], [124, 271, 282, 285], [124, 392, 336, 406], [124, 392, 336, 406], [124, 392, 336, 406], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [125, 413, 854, 431], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 436, 677, 452], [124, 500, 653, 515], [124, 500, 653, 515], [124, 500, 653, 515], [124, 500, 653, 515], [124, 500, 653, 515], [124, 500, 653, 515], [124, 500, 653, 515], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [125, 522, 803, 538], [124, 545, 392, 559], [124, 545, 392, 559], [124, 545, 392, 559], [124, 545, 392, 559], [124, 545, 392, 559], [124, 545, 392, 559], [124, 545, 392, 559], [124, 737, 778, 754], [124, 737, 778, 754], [124, 737, 778, 754], [124, 737, 778, 754], [124, 737, 778, 754], [124, 737, 778, 754], [124, 7 ...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/82250337_0338.png'}
# 82251504
# {'id': '82251504', 'tokens': ['11/05/97', '11:', '03', 'Additional', 'monies', 'have', 'assisted', 'Region', '17', 'in', 'fighting', 'PM', 'Exclusives', 'and', 'PM/', 'RJR', 'Chains:', 'This', 'program', 'has', 'been', 'successful', 'to', 'date', 'with', 'chains', 'where', 'our', '"Flex', 'Payment".', 'was', 'not', 'in', 'place.', 'The', 'chains', 'where', 'we', 'were', 'using', 'the', '"Flex', 'Payment"', 'system', 'we', 'have', 'not', 'been', 'las', 'successful.', 'The', 'P.', 'O.', 'S.', 'requirements', 'of', 'the', 'P-', '1', 'Plan', 'with', 'Oil', 'Companies', 'is', 'difficult', 'to', 'obtain.', 'Additional', 'P.', 'V.', 'merchandising', 'is', 'being', 'secured', 'quickly,', 'The', 'displays', 'are', 'easily', 'assembled', 'and', 'durable.', 'Some', 'questions', 'have', 'been', 'raised', 'conceming', 'the', 'inability', 'to', 'be', 'flush', 'with', 'the', 'counter', 'and/', 'or', 'up', 'against', 'the', 'register.', 'As', 'well', 'as', 'the', 'ability', 'to', 'place', 'this', 'or', 'the', 'Back', 'Bar', 'if', 'the', 'settlement', 'goes', 'through', 'Pemanent', 'Advertising', 'Evaluation/', 'Effectiveness/', 'Acceptance:', '(P-', '1/', 'P-', '5', '&', 'C', '5', 'Plans', 'Only:', 'Independents:', 'co-existence', 'situations.', 'Hardware', 'Evaluation/', 'Effectiveness:', 'Comment', 'on', 'the', 'assembly', 'of', 'displays', 'and', 'application', 'of', 'shields:', 'Acceptance/', 'Response:', 'What', 'is', 'the', 'retailers', 'response', 'to', "Lorillard's", 'Excel', 'Merchandising', 'plan?', 'October', '31', 'Submission', 'for:', 'July', '31', 'November', '28', 'December', '30', 'August', '29', 'September', '30', 'X', 'Not', 'available', 'at', 'this', 'time', '813', '384', '0683', 'Retail', 'Excel', 'Progress', 'Report', ':', 'From:', 'Area:', '5', 'Region:', 'R.', 'W.', 'Caldarella', 'Kent', 'B.', 'Mills', 'LORILLARD', 'TAMPA', 'GREENSBOR', '17', 'DM', 'to', 'RSM', '1st', 'of', 'Month', 'RSM', 'to', 'R', 'W.', 'C.', '10th', 'cc:', 'D.', 'O.', 'S.', 'Distribution', 'by/', 'to:', '<unk>', '<unk>', '<unk>', '0002/', '003', '82251504'], 'bboxes': [[92, 89, 229, 101], [92, 89, 229, 101], [92, 89, 229, 101], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [107, 522, 774, 543], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387], [115, 366, 754, 387],
'$', '(Indicate', "Distributor's", 'Cost', 'Per', 'Carton)', 'COMPETITIVE', 'PRODUCT', 'INTRODUCTION', '317', '8450977', '(Forward', 'by', 'the', '10th', 'of', 'the', 'following', 'month.)', 'All', 'of', 'Region', '7.', 'AUG', 'PROGRESS', 'REPORT', 'MANUFACTURER', 'R.', 'J.', 'Reynolds', 'BRAND:', 'Camel', 'Menthol', 'TYPE', 'OF', 'PACKINGS:', 'Full', 'Flavor', 'Box', 'and', 'Light', 'Box', 'PAGE', '1', 'OF', '2', 'LORILLARD', 'SEPT', 'OCT', '82253058', 'NOV', 'X', '001/', '002'], 'bboxes': [[84, 925, 209, 940], [84, 925, 209, 940], [84, 925, 209, 940], [111, 56, 253, 70], [111, 56, 253, 70], [111, 56, 253, 70], [111, 56, 253, 70], [111, 56, 253, 70], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [372, 412, 855, 429], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 430, 765, 447], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [120, 506, 795, 523], [122, 278, 302, 295], [122, 278, 302, 295], [122, 335, 350, 350], [122, 335, 350, 350], [122, 335, 350, 350], [122, 374, 236, 389], [122, 374, 236, 389], [122, 411, 360, 427], [122, 411, 360, 427], [122, 411, 360, 427], [122, 582, 356, 596], [122, 582, 356, 596], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [122, 602, 846, 620], [125, 620, 299, 637], [125, 620, 299, 637], [125, 620, 299, 637], [122, 774, 627, 789], [122, 774, 627, 789], [122, 774, 627, 789], [122, 774, 627, 789], [122, 774, 627, 789], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [122, 792, 655, 808], [124, 203, 152, 217], [124, 222, 176, 236], [124, 242, 172, 256], [124, 4 ...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/82253058_3059.png'}
# 82253245_3247
# {'id': '82253245_3247', 'tokens': ['Sicc', 'Serva', 'TO:', 'DIRECT', 'ACCOUNTS', 'AND', 'CHAINS', 'HEADQUARTERED', 'WITHIN', 'THE', 'REGION', 'M.', 'Maskos', '&', 'Sons', 'DIRECT', 'ACCOUNTS', 'AND', 'CHAINS', 'HEADQUARTERED', 'OUTSIDE', 'THE', 'REGION', 'W', 'H', 'Smith', 'Dairy', 'Marts', 'FROM:', '(Report', 'on', 'June', '30', 'only)', 'BIGIF', '2', 'FOR', '1:', 'Proved', 'to', 'be', 'an', 'excellent', 'tool', 'for', 'pulling', 'the', 'balance', 'of', 'Style', 'Full', 'Price', 'packs', 'through', 'the', 'system.', 'This', 'aided', 'the', 'field', 'greatly', 'during', 'the', 'transition', 'Sheetz', '(15+', 'STORES)', 'STOCKING', 'NO', 'LOW', 'PRICE', 'STYLE', 'Kroger', 'Rich', 'Oil', 'Super', 'America', 'SUBJECT:', 'PRE-', 'SELL', '$', '7.00', 'CARTON', 'COUPON/', 'BUYDOWN:', '(15+', 'STORES)', 'STOCKING', 'NO', 'LOW', 'PRICE', 'STYLE', 'cvs', '7-', '11', '318', 'Zon', 'Overall', 'pre-', 'sell', 'efforts', 'were', 'successful', 'Retail', 'accounts', 'that', 'previously', 'stocked', 'Style', 'Full', 'Price', 'accepted', 'the', 'introduction', 'of', 'the', 'low', 'price', 'Effective', 'in', 'those', 'retail', 'calls', 'that', 'we', 'could', 'not', 'exchange', 'product', 'out', '
...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/82253245_3247.png'}
# 82253362_3364
# {'id': '82253362_3364', 'tokens': ['Eckerd', 'Drugs', 'S.', 'Texas', 'FROM:', 'SUBJECT:', '(ONLY', 'IF', 'PARTIAL', 'REGION', 'CONTINUE', 'WITH', 'DIVISION', '(S)', 'SCOPE)', 'DIVISION:', '(15+', 'STORES)', 'STOCKING', 'NO', 'MAVERICK', 'SPECIALS', 'MENTHOL', 'Don', '&', 'Bens', 'Western', 'Beverage', 'Speedy', 'Stop', 'Get', 'N', 'Go', 'Valley', 'Shamrock', "Albertson's", '-Houston', 'Mini', 'Mart', 'Neal', 'One', 'Stop', 'Shopper', 'Mart', '(15+', 'STORES)', 'STOCKING', 'NO', 'MAVERICK', 'SPECIALS', 'MENTHOL', 'Brookshire', "Bro's", 'Exxon', "Philip's", '66', 'Star', 'Enterprise', "Walgreen's", 'TO:', 'REGION:', 'Chevron', 'DIRECT', 'ACCOUNTS', 'AND', 'CHAINS', 'HEADQUARTERED', 'WITHIN', 'THE', 'REGION', 'DIRECT', 'ACCOUNTS', 'AND', 'CHAINS', 'HEADQUARTERED', 'OUTSIDE', 'THE', 'REGION', 'NAME', 'OF', 'ACCOUNT', 'NAME', 'OF', 'ACCOUNT', 'DIVISION', 'NAME:', 'DIVISION', 'NAME:', 'DIVISION', 'NAME:', 'MAVPROGO', 'DISTRIBUTION', 'GEOGRAPHY', 'K.', 'A.', 'Sparrow', 'J.', 'L.', 'McGinnis', 'MAVERICK', 'SPECIALS', 'MENTHOL', '-', 'PROGRESS', 'REPORT', 'IND/', 'LOR', 'VOLUME', 'IND/', 'LOR', 'VOLUME', '319/', '16', '106', '/4', '42/', '2', '26/', '2', '62/', '2', '78/', '4', '65/', '3', '69/', '3', '80/', '4', '?', '?', '?', '?', '?', '?', '?', 'FULL', 'FULL', 'DIVISION', 'NAME:', 'DIVISION', 'NAME:', 'DIVISION', 'NAME:', 'NO.', 'OF', 'STORES', 'NO.', 'OF', 'STORES', '20', '115', '217', '177', '15', '17', '20', '22', '38', '38', '70', '29', '44', '34', '15', '27', 'X', 'Lone', 'Star', 'Sac', 'N', 'Pac', 'ACO', 'Texaco', 'NAME', 'OF', 'ACCOUNT', 'NAME', 'OF', 'ACCOUNTS', 'MAY', '19', '☐', 'JUN', '30', '☐', '#', 'REPS', '#', 'REPS', 'PARTIAL', 'PARTIAL', '#', 'REPS', 'IND/', 'LOR', 'VOLUME', 'IND/', 'LOR', 'VOLUME', '76/', '3', '75/', '2', '95/', '3', 'SUBMISSION', 'DATE', 'NO.', 'OF', 'STORES', 'NO.', 'OF', 'STORES', '37', 'AUG', '11', '☐', '27', '15', 'SEP', '22', '☑', 'Page', '1', 'of', '3', 'Pages', '82253362'], 'bboxes': [[75, 701, 210, 715], [75, 701, 210, 715], [75, 701, 210, 715], [75, 701, 210, 715], [78, 113, 120, 126], [78, 162, 140, 175], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 236, 466, 250], [78, 261, 137, 274], [78, 394, 450, 406], [78, 394, 450, 406], [78, 394, 450, 406], [78, 394, 450, 406], [78, 394, 450, 406], [78, 394, 450, 406], [78, 394, 450, 406], [78, 436, 148, 449], [78, 436, 148, 449], [78, 436, 148, 449], [78, 453, 177, 466], [78, 453, 177, 466], [78, 472, 148, 486], [78, 472, 148, 486], [78, 489, 133, 501], [78, 489, 133, 501], [78, 489, 133, 501], [78, 506, 169, 520], [78, 506, 169, 520], [78, 521, 194, 537], [78, 521, 194, 537], [78
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/89856243.png'}
# 91814768_91814769
# {'id': '91814768_91814769', 'tokens': ['<unk>', '<unk>', 'File', 'with:', '2.', 'Name', 'of', 'Corporation', '1.', 'Name', 'of', 'Treasurer', '3.', 'Address', 'of', 'Corporation', '4.', 'Question', 'No.', 'submitted', 'to', 'the', 'voters', 'on', 'I', 'certify', 'that', 'this', 'report', 'is', 'a', 'true', 'statement', 'of', 'the', 'amount', 'of', 'value', 'of', 'every', 'gift,', 'payment,', 'expenditure', 'or', 'or', 'promise', 'to', 'give,', 'pay,,', 'expend', 'or', 'contribute,', 'together', 'with', 'the', 'date,', 'purpose,', 'and', 'full', 'name', 'and', 'address', 'of', 'the', 'person', 'to', 'whom', 'It', 'was', 'made.', 'I', 'make', 'this', 'report', 'in', 'accordance', 'with', 'the', 'requirements', 'of', 'Mass.', 'General', 'Laws,', 'Chapter,', 'Section,', 'as', 'amended.', '*Note:', 'Signed under', 'the', 'penalties', 'of', 'perjury.', 'Preasurer', 'Senato', 'Assistant', 'Treasurer', '**In-', 'kind', 'contributions', 'should', 'be', 'included', 'here.', '10/', '30/', '92', '10/', '26/', '92', 'Attach', 'additional', 'pages', 'if', 'necessary.', 'Please', 'Print', 'or', 'Type,', 'except', 'Signatures.', 'Fil', 'in', 'Dates:', 'Date', 'Paid', 'REPORT', 'OF', 'CORPORATE', 'TREASURER', 'If', 'this', 'expenditure', 'is', 'made', 'to', 'influence', 'a', 'local', 'ballot', 'question,', 'a', 'copy', 'of', 'this', 'form', 'should', 'be', 'filed', 'with', 'the', 'city', 'or', 'town', 'clerk', 'or', 'election', 'commission.', 'Director,', 'Office', 'of', 'Campaign', '&', 'Political', 'Finance', 'One', 'Ashburton', 'Place,', 'Boston,', 'MA', '02108', '<unk>', 'Committee', 'Against', 'Unfair', 'Taxes', 'Committee', 'Against', 'Unfair', 'Taxes', 'To', 'Whom', 'Paid', '(Alphabetical', 'Listing', 'Mandatory)', 'REPORTING', 'REQUIREMENTS', 'CONTINUED ON', 'REVERSE', 'SIDE', '1', 'relating', 'to', 'Tobacco', 'Excise', 'Tax', 'Increase', 'M.', 'Alfred', 'Peterson;', 'Assistant', 'Treasurer', 'Peter', 'J.', 'Marzullo', 'Reporting', 'Period', 'Beginning', '"CORRECTED', 'FORM"', 'The', 'Commonwealth', 'of', 'Massachusetts', 'OFFICE', 'OF', 'CAMPAIGN', 'AND', 'POLITICAL', 'FINANCE', 'November', '3,', '1992', 'One', 'Park', 'Avenue', 'New', 'York.', 'NY', '10016', '-5895', 'Lorillard', 'Tobacco', 'Company', '(Election', 'Date)', 'EXPENDITURES', 'OR', 'DISBURSEMENTS', 'on', 'the', 'October', '16,', '<unk>', 'P.', 'O.', 'B03', '5979', 'Boston,', 'MA', '0212', 'P.', 'O.', 'Box', '5979.', 'Boston,', 'MA', '02114', 'Total', 'Expenditures', 'for', 'Disbursements', 'Previously', 'Reported', 'March', '30,', '1993', 'Massachusetts', 'Total', 'Expenditures', 'or', 'Disbursements', 'on', 'This', 'Report', 'Total', 'Expenditures', 'or', 'Disbursements', 'to', 'Date', '(Describe', 'question', 'briefly)', '(formerly', 'CPF', '10)', 'Address', '19', 'Form', 'CPF', '22', '(Name', 'of', 'City/', 'Town', 'of', 'State)*', '92', 'Date', 'and', 'Ending', 'November', '5.', '1992', '☐', '20th', 'Day', 'of', 'the', 'Month', '☐', '60th', 'Day', 'Prior', 'to', 'Election', '☑', 'Final', '☐', '5th', 'Day', 'of', 'the', 'Month', 'Oppose', 'Tax', 'Increase', 'Oppose', 'Tax', 'increas', 'Purpose', 'Office', 'Use', 'Only', '(CHECK', 'ONE)', 'contribution', 'Amount', 'or', 'Value**', '508.', '789', '00', '556', '874.', '00', '48,', '585', '00', '28,', '482.', '00', '19,', '503', '00', 'ballot', '91814768'], 'bboxes': [[50, 236, 95, 258], [55, 494, 101, 523], [66, 172, 137, 192], [66, 172, 137, 192], [68, 295, 244, 310], [68, 295, 244, 310], [68, 295, 244, 310], [68, 295, 244, 310], [72, 270, 227, 288], [72, 270, 227, 288], [72, 270, 227, 288], [72, 270, 227, 288], [72, 318, 262, 336], [72, 318, 262, 336], [72, 318, 262, 336], [72, 318, 262, 336], [72, 373, 184, 393], [72, 373, 184, 393], [72, 373, 184, 393], [72, 416, 258, 436], [72, 416, 258, 436], [72, 416, 258, 436], [72, 416, 258, 436], [72, 416, 258, 436], [72, 518, 951, 542], [72, 518, 951, 542], [72, 518, 951, 542], [72, 518, 951, 542], [72, 518, 951, 542], [72, 518, 951, 542], [72, 518, 951, 542], [72, 518, 951, 5 ...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [155, 255, 255,  ..., 255, 255, 255],
#          [201, 255, 255,  ..., 255, 255, 255],
#          [244, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [155, 255, 255,  ..., 255, 255, 255],
#          [201, 255, 255,  ..., 255, 255, 255],
#          [244, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [155, 255, 255,  ..., 255, 255, 255],
#          [201, 255, 255,  ..., 255, 255, 255],
#          [244, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/91814768_91814769.png'}
# 92380595
# {'id': '92380595', 'tokens': ['United', 'States', 'Corporation', 'Company', 'DATE:', 'TO:', 'RE:', 'TITLE', 'OF', 'ACTION:', 'vs.', 'COURT', 'OR', 'JURISDICTION', 'Tel', 'Call', 'Placed', 'Direct', 'ATTORNEYS', 'FOR', 'CLAIMANT', 'PLEASE', 'ACKNOWLEDGE', 'RECEIPT', 'OF', 'THIS', 'NOTICE', 'AND', 'THE', 'ENCLOSURES', 'BY', 'SIGNING', 'AND', 'RETURNING', 'THE', 'Date', 'Received:', 'RETURN', 'DATE', 'COMMENTS:', 'PAPERS', 'TRANSMITTED', 'TO', 'CLIENT', 'Other', 'DUPLICATE', 'COPY', 'A', 'BUSINESS', 'REPLY', 'ENVELOPE', 'IS', 'ENCLOSED', 'FOR', 'YOUR', 'CONVENIENCE', 'Fed', 'X', 'as', 'registered', 'agent', 'for', 'the', 'above-', 'captioned', 'corporation', 'on', 'X', 'We', 'enclose', 'the', 'following', 'documents', 'which', 'were', 'served', 'upon:', 'Summons', 'Complaint', 'Duplicate', 'copies', 'of', 'the', 'Notice', 'and', 'Acknowledgement', 'enclosed', 'Other:', '12-', '13-', '89', 'LORILL
...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/92380595.png'}
# 93106788
# {'id': '93106788', 'tokens': ['B.', 'Please', 'inspect', 'repro', 'material', 'immediately.', 'C.', 'Poor', 'printing', 'will', 'not', 'be', 'paid', 'for.', 'E.', 'Under', 'no', 'circumstances', 'are', 'you', 'to', 'space', 'APPROVAL', 'FROM', 'LORILLARD', 'MEDIA', 'SERVICES.', 'AD#:', 'IF', 'UNABLE', 'TO', 'INSERT', 'ON', 'THE', 'DATE', 'ORDERED', 'KINDLY', 'NOTIFY', 'US', 'AT', 'ONCE', 'AND', 'WAIT', 'FOR', 'NEW', 'INSERTION', 'DATE.', 'NO', 'CREDIT', 'POSITION', 'URGENTLY', 'REQUESTED:', 'FAR', 'FORWARD,', 'OPPOSITE', 'FULL', 'EDITORIAL', '-', 'No', 'coupon', 'ad', 'on', 'backing', 'page.', '-', 'No', 'aditional/', 'advertising', 'matter', 'to', 'cigarette', 'within', '6', 'pages', 'of', 'our', 'ad.', 'COPY', 'INSTRUCTIONS:', '5', 'COLOR', 'PROOF', 'ATTACHED,', 'FILM', 'FROM', 'COLLIER', 'WITH', '"D"', 'WARNING', 'IMPORTANT', 'INSTRUCTIONS:', 'A.', 'Check', 'material', 'carefully', 'against', 'proof', 'D.', 'Advise', 'us', 'at', 'once', 'if', 'instructions', 'are', 'not', 'THIS', 'ADVERTISEMENT', 'COMPLIES', 'WITH', 'THE', 'FTC', 'REQUIREMENT', 'FOR', 'A', 'WARNING', 'STATEMENT', 'AND', 'TAR', 'AND', 'NICOTINE', 'LINE', 'WHICH', 'MUST', 'APPEAR', 'IN', 'ALL', 'CIGARETTE', 'ADVERTISING', 'CHECK', 'MATERIAL', 'YOU', 'RECEIVE', 'AGAINST', 'THE', 'PROOF', 'TO', 'BE', 'SURE', 'IT', 'IS', 'CORRECT,', 'UNDER', 'NO', 'CIRCUMSTANCES', 'ARE', 'TO', 'YOU', 'RUN', 'SUBSTITUTE', 'MATERIALS,', 'ALTERIOR', 'OR', 'OMIT', 'ANY', 'COPY', 'WITHOUT', 'PRIOR', 'NPT-', '533-', '7', 'PO', 'CAN', 'BE', 'ALLOWED', 'SHOULD', 'THIS', 'ADVERTISEMENT', 'APPEAR', 'INCORRECTLY', 'OR', 'ON', 'A', 'DATE', 'OTHER', 'THAN', 'THAT', 'AUTHORIZED.', 'TO:', '#77219', 'to', 'make', 'sure', 'it', 'corresponds', 'in', 'every', 'They', 'should', 'produce', 'good', 'printing', 'results.', 'Advise', 'us', 'promptly', 'if', 'Hor', 'satisfactory', 'respect', 'clear.', 'out', 'our', 'advertisement', 'without', 'specific', 'instructions', 'from', 'us.', 'ESSENCE', '1500', 'BROADWAY', 'NEW', 'YORK,', 'NY', '10036', 'ATTN:', 'JOYCE', 'WINSTON', 'LORILLARD', 'MEDIA', 'SERVICES', 'ONE', 'PARK', 'AVENUE,', 'NEW', 'YORK,', 'NY', '10016-', '5896', 'MAGAZINE', 'INSERTION', 'ORDER', 'CAPTION:', 'FOUNTAIN', 'COUPLE', '-', 'Maintain', 'at', 'least', 'six', 'page', 'separation', 'from', 'bompetitive', 'ads.', 'SPACE:', 'P5CE', 'The', 'space', 'is', 'being', 'brdered', 'by:', 'of', 'all', 'regional', 'and', 'national', 'additions', 'to:', 'ATTN:', 'STEVE', 'MOLLOY', 'SPACE BILLING', 'INSTRUCTIONS:', 'LOAILLARD', 'MEDIA', 'SERVICES', 'Direct', 'all', 'invoices', 'and', 'full', 'checking', 'copies', 'LORILLARD', 'MEDIA', 'SERVICES', 'NEW', 'YORK', 'NEW', 'YORK', '10016-', '5896', 'ONE', 'PARK', 'AVENUE', '17TH', 'FLOOR', 'Smoke', 'contains', 'carbon', 'Monoxide', 'SURGEON', 'GENERALS', 'WARNING', 'Cigarette', 'ADVERTISER:', 'PRODUCT:', 'DATE:', 'DATE:', 'JUNE', '1995', 'LORILLARD', 'MARCH', '17,', '1995', 'NEWPORT', '93106788'], 'bboxes': [[125, 744, 383, 755], [125, 744, 383, 755], [125, 744, 383, 755], [125, 744, 383, 755], [125, 744, 383, 755], [125, 744, 383, 755], [125, 786, 331, 798], [125, 786, 331, 798], [125, 786, 331, 798], [125, 786, 331, 798], [125, 786, 331, 798], [125, 786, 331, 798], [125, 786, 331, 798], [125, 786, 331, 798], [125, 839, 380, 851], [125, 839, 380, 851], [125, 839, 380, 851], [125, 839, 380, 851], [125, 839, 380, 851], [125, 839, 380, 851], [125, 839, 380, 851], [125, 839, 380, 851], [127, 339, 405, 354], [127, 339, 405, 354], [127, 339, 405, 354], [127, 339, 405, 354], [127, 339, 405, 354], [127, 376, 159, 387], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478, 859, 492], [127, 478,  ...
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]],
#
#         [[255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          ...,
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255],
#          [255, 255, 255,  ..., 255, 255, 255]]], dtype=torch.uint8), 'image_path': '/root/.cache/huggingface/datasets/downloads/extracted/e5bbbc543f8cc95554da124f3e80a57ed24d67d06ae1467da5810703f851e3f9/dataset/testing_data/images/93106788.png'}

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=1)
from layoutlmft.models.layoutlmv3.modeling_layoutlmv3 import LayoutLMv3ForRelationExtraction
# validate model output
from transformers import AutoConfig
config = AutoConfig.from_pretrained(
    "results/layoutlmv3-base-finetuned-funsd-re/",
    input_size=224,
    num_labels=2,
    finetuning_task="re",
)
model = LayoutLMv3ForRelationExtraction.from_pretrained(
    "results/layoutlmv3-base-finetuned-funsd-re/",
)

# %%
next(iter(train_loader))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 next(iter(train_loader))
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/torch/_tensor.py:249, in Tensor.__repr__(self)
#     247     return handle_torch_function(Tensor.__repr__, (self,), self)
#     248 # All strings are unicode in Python 3.
# --> 249 return torch._tensor_str._str(self)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/torch/_tensor_str.py:415, in _str(self)
#     413 def _str(self):
#     414     with torch.no_grad():
# --> 415         return _str_intern(self)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/torch/_tensor_str.py:390, in _str_intern(inp)
#     388                 tensor_str = _tensor_str(self.to_dense(), indent)
#     389             else:
# --> 390                 tensor_str = _tensor_str(self, indent)
#     392 if self.layout != torch.strided:
#     393     suffixes.append('layout=' + str(self.layout))
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/torch/_tensor_str.py:251, in _tensor_str(self, indent)
#     249     return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     250 else:
# --> 251     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     252     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~/mambaforge/envs/env/lib/python3.8/site-packages/torch/_tensor_str.py:99, in _Formatter.__init__(self, tensor)
#      97 nonzero_finite_abs = nonzero_finite_vals.abs().double()
#      98 nonzero_finite_min = nonzero_finite_abs.min().double()
# ---> 99 nonzero_finite_max = nonzero_finite_abs.max().double()
#     101 for value in nonzero_finite_vals:
#     102     if value != torch.ceil(value):
#
# KeyboardInterrupt:
